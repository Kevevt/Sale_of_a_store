# %% [markdown]
# ## Practicando con Pandas, Ejercicio de Inmueble

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# #### 1. **Importando la base de datos**

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep =';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep =';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(11)
# Out:
#                        Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                  Cocineta           Condesa             1        0       0
# 1                      Casa           Polanco             2        0       1
# 2   Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3              Departamento  Centro Histórico             1        0       0
# 4              Departamento         Del Valle             1        0       0
# 5        Casa de Condominio          Santa Fe             5        4       5
# 6   Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7              Departamento  Centro Histórico             1        0       0
# 8              Departamento           Condesa             1        0       1
# 9                  Cocineta           Condesa             1        0       0
# 10             Departamento           Condesa             4        3       1
#
#     Area     Valor  Condominio  Impuesto
# ...

# %%
datos.sample(10)
# Out:
#                              Tipo               Colonia  Habitaciones  \
# 15117                Departamento              Santa Fe             1
# 11257                Departamento  Lomas de Chapultepec             1
# 9725                 Tienda/Salón              Santa Fe             0
# 8812                 Departamento            La Florida             2
# 8603      Conjunto Comercial/Sala      Centro Histórico             0
# 15894  Tienda en Centro Comercial              Santa Fe             0
# 20678                Departamento              Santa Fe             2
# 4305      Conjunto Comercial/Sala              Santa Fe             0
# 21257     Conjunto Comercial/Sala      Centro Histórico             0
# 1515      Conjunto Comercial/Sala               Polanco             0
#
#        Garages  Suites  Area     Valor  Condominio  Impuesto
# 15117        1       0    70    9800.0      4375.0     766.5
# 11257        1       0    82    6650.0      5950.0    1218.0
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **Exploración inicial de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 5232              Departamento               Condesa             1        0
# 15758             Departamento  Bosques de las Lomas             3        2
# 13850  Conjunto Comercial/Sala              Santa Fe             0        7
# 23368             Departamento             Del Valle             2        1
# 19083             Departamento    Villa de Guadalupe             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 5232        1    40   5250.0      1911.0       NaN
# 15758       1   400  56000.0     13440.0    6370.0
# 13850       0   250  52500.0         NaN       NaN
# 23368       1    90  11550.0      6527.5     903.0
# 19083       1    62   6300.0      2100.0     220.5

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Tipo', 'Area']]
# Out:
#                           Tipo  Area
# 0                     Cocineta    40
# 1                         Casa   100
# 2      Conjunto Comercial/Sala   150
# 3                 Departamento    15
# 4                 Departamento    48
# ...                        ...   ...
# 25116  Cochera/Estacionamiento   755
# 25117                 Cocineta    27
# 25118             Departamento    48
# 25119             Departamento    70
# 25120  Conjunto Comercial/Sala   250
#
# [25121 rows x 2 columns]

# %% [markdown]
# #### Ejemplo de ONE

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datoss = pd.read_csv(url)

# %%
datoss.info
# Out:
# <bound method DataFrame.info of       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero>

# %%
datos.describe()
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %% [markdown]
# ## **Demandas de ML**

# %% [markdown]
# #### ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos['Valor'].mean().round(2)
# Out:
# np.float64(36885.05)

# %%
datos['Valor'].isna().sum() 
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.dtypes
# Out:
# Tipo             object
# Colonia          object
# Habitaciones      int64
# Garages           int64
# Suites            int64
# Area              int64
# Valor           float64
# Condominio      float64
# Impuesto        float64
# dtype: object

# %%
datos.groupby('Tipo').mean(numeric_only=True).round(2)
# Out:
#                             Habitaciones  Garages  Suites      Area  \
# Tipo
# Casa                                3.36     1.90    1.44    289.94
# Casa Comercial                      1.80     2.12    0.26    370.28
# Casa de Condominio                  4.32     3.56    3.25    566.30
# Casa de Vecindad                    1.97     0.38    0.22     79.98
# Cochera/Estacionamiento             0.06     1.38    0.00     18.66
# Cocineta                            0.84     0.02    0.04     29.09
# Conjunto Comercial/Sala             0.05     2.69    0.00    236.32
# Departamento                        2.50     1.26    0.89    124.01
# Departamento en Hotel               1.42     0.97    0.76     65.85
# Edificio Completo                   0.41    11.18    0.03   1717.27
# Estudio                             0.50     0.25    0.00    103.25
# Galpón/Depósito/Almacén             0.07     5.31    0.00   2660.49
# Hotel                              25.50     2.50   12.00    885.50
# ...

# %%
datos.groupby('Tipo')['Valor'].mean(numeric_only=True).round(2).sort_values()
# Out:
# Tipo
# Cocineta                        4425.86
# Posada/Chalé                    5180.00
# Casa de Vecindad                5961.74
# Cochera/Estacionamiento         6995.45
# Estudio                         8400.00
# Loft                            9924.53
# Departamento en Hotel          16285.43
# Departamento                   18683.27
# Casa                           31453.18
# Tienda en Centro Comercial     32556.79
# Rancho                         38014.38
# Casa de Condominio             51428.61
# Casa Comercial                 54735.84
# Tienda/Salón                   56263.54
# Conjunto Comercial/Sala        57675.21
# Hotel                          87500.00
# Loteo/Condominio               92166.67
# Terreno Estándar              135364.44
# Galpón/Depósito/Almacén       299984.14
# Edificio Completo             409418.08
# Industria                     420000.00
# Name: Valor, dtype: float64

# %%
datos.groupby('Tipo')[['Valor','Impuesto']].mean(numeric_only=True).round(2).sort_values('Valor')
# Out:
#                                 Valor  Impuesto
# Tipo
# Cocineta                      4425.86    280.70
# Posada/Chalé                  5180.00       NaN
# Casa de Vecindad              5961.74    706.85
# Cochera/Estacionamiento       6995.45    449.46
# Estudio                       8400.00    529.38
# Loft                          9924.53    887.08
# Departamento en Hotel        16285.43   1768.92
# Departamento                 18683.27   2634.92
# Casa                         31453.18   6629.40
# Tienda en Centro Comercial   32556.79   4127.76
# Rancho                       38014.38   4375.00
# Casa de Condominio           51428.61  15046.94
# Casa Comercial               54735.84   6166.06
# Tienda/Salón                 56263.54  10532.47
# Conjunto Comercial/Sala      57675.21   5425.98
# Hotel                        87500.00  21707.00
# Loteo/Condominio             92166.67  17097.50
# Terreno Estándar            135364.44  24988.75
# ...

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor','Impuesto']].mean(numeric_only=True).round(2).sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8),color='purple')
df_tipo_precio.plot(kind='bar')
# Out:
# <Axes: xlabel='Tipo'>

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.Colonia.unique()
# Out:
# array(['Condesa', 'Polanco', 'Santa Fe', 'Centro Histórico', 'Del Valle',
#        'Roma', 'Narvarte', 'Lomas de Chapultepec', 'Coyoacán',
#        'San Pedro de los Pinos', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Villa Coapa', 'Bosques de las Lomas',
#        'Juárez', 'Chapultepec', 'Lindavista', 'La Condesa',
#        'San Miguel Chapultepec', 'Mixcoac', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Bosques de Aragón', 'La Florida', 'Álvaro Obregón', 'Iztacalco',
#        'Peralvillo', 'Napoles', 'Nativitas', 'San Rafael', 'Vallejo',
#        'Tlalpan', 'Pueblo Culhuacán', 'San Antonio Tecomitl',
#        'Roma Norte', 'Industrial Vallejo', 'Iztapalapa',
#        'Santa Marta Acatitla', 'Villa de Guadalupe', 'Tláhuac',
#        'Lomas de Padierna', 'El Contadero', 'San Mateo', 'Las Águilas',
#        'Culhuacán CTM', 'Santa María la Ribera', 'El Arenal',
# ...

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial', 'Terreno Estándar',
                          'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio', 'Industria']

# %%
datos.query(f'Tipo not in {inmuebles_comerciales}')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query(f'Tipo not in {inmuebles_comerciales}')
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %% [markdown]
# ####  **1.) ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?**

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor','Impuesto']].mean(numeric_only=True).round(2).sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8))
df_tipo_precio.plot(kind='bar')
# Out:
# <Axes: xlabel='Tipo'>

# %% [markdown]
# ####  **2.) Porcentaje de cada tipo de inmueble presente en la base de datos**

# %%
df.Tipo.value_counts(normalize=True).round(2)
# Out:
# Tipo
# Departamento             0.85
# Cocineta                 0.04
# Casa de Condominio       0.04
# Casa                     0.03
# Departamento en Hotel    0.03
# Casa de Vecindad         0.01
# Loft                     0.00
# Rancho                   0.00
# Estudio                  0.00
# Posada/Chalé             0.00
# Name: proportion, dtype: float64

# %%
df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
daf = df.query('Tipo == "Departamento"')
daf.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).round(2)
porcentaje_tipo.head()
porcentaje_tipo.plot(kind='bar', color = 'green', xlabel='Tipos', ylabel='Porcentaje' )
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentaje'>

# %%
df_tipo_precio = daf.groupby('Tipo')[['Valor','Impuesto']].mean(numeric_only=True).round(2).sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8))
df_tipo_precio.plot(kind='bar')
# Out:
# <Axes: xlabel='Tipo'>

# %%
daf.shape
# Out:
# (14764, 9)

# %% [markdown]
# ### **Tareas Extras:**

# %% [markdown]
# #### 1. Calcular el promedio de habitaciones por departamento.

# %%
daf.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
daf.Habitaciones.mean(numeric_only=True)
# Out:
# np.float64(2.5041994039555675)

# %%
daf['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %% [markdown]
# ### 2. Verificar cuántas colonias únicas existen en nuestra base de datos.

# %%
daf.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
len(daf.Colonia.unique())
# Out:
# 83

# %%
daf['Colonia'].nunique()
# Out:
# 83

# %%
daf.groupby('Colonia')[['Valor']].mean().round(2).sort_values('Valor', ascending=False)
# Out:
#                               Valor
# Colonia
# Los Alpes                  54250.00
# Bosques de Aragón          35948.72
# Coyoacán                   33205.22
# Roma                       32530.39
# Lomas de Chapultepec       30232.17
# ...                             ...
# El Rodeo                    2275.00
# Tláhuac                     2275.00
# San Antonio Tecomitl        2065.00
# Santa María Aztahuacán      1785.00
# Potrero de San Bernardino   1190.00
#
# [83 rows x 1 columns]

# %%
daf.groupby('Colonia')[['Valor']].mean().round(2).sort_values('Valor',ascending=False).head(3).plot(kind='barh',xlabel='Valor en MXN', ylabel='Colonia')
# Out:
# <Axes: xlabel='Valor en MXN', ylabel='Colonia'>

# %%
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %% [markdown]
# ## **Tratamiento de datos Nulos.**

# %%
daf.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
daf.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
daf.Impuesto.sum()
# Out:
# np.float64(28897179.5)

# %%
daf= daf.fillna(0)

# %%
daf.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ## **Remover registros inconsistentes**

# %%
daf.query('Valor == 0 | Condominio == 0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
daf.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover = daf.query('Valor == 0 | Condominio == 0').index

# %%
daf.drop(df_remover,axis=0,inplace=True)

# %%
daf.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
daf.shape
# Out:
# (14264, 9)

# %%
daf.drop('Tipo',axis=1,inplace=True)
daf.head()
# Out:
#              Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3   Centro Histórico             1        0       0    15   2800.0
# 4          Del Valle             1        0       0    48   2800.0
# 8            Condesa             1        0       1    40   7000.0
# 10           Condesa             4        3       1   243  45500.0
# 13          Santa Fe             2        1       1    67   5950.0
#
#     Condominio  Impuesto
# 3       1365.0      70.0
# 4        805.0       0.0
# 8       1963.5     175.0
# 10      7000.0    2810.5
# 13      2061.5     514.5

# %% [markdown]
# ## **Creando filtros**

# %% [markdown]
# ### 1.) Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
seleccion1 = daf['Habitaciones'] == 1

# %%
daf_1_habitacion = daf[seleccion1]
daf_1_habitacion.sample(5)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 24388                Santa Fe             1        1       1    60  6300.0
# 5926                  Condesa             1        0       1    40  6300.0
# 10564  San Pedro de los Pinos             1        1       0    65  7350.0
# 11256  Ciudad de los Deportes             1        0       0    60  2625.0
# 13174                    Roma             1        0       1    45  5600.0
#
#        Condominio  Impuesto
# 24388      3500.0     896.0
# 5926        588.0     413.0
# 10564      4452.0     574.0
# 11256       105.0       0.0
# 13174       945.0     269.5

# %%
seleccion2 = daf_1_habitacion['Valor'] <4200
daf_1_habitacion = daf_1_habitacion[seleccion2]
daf_1_habitacion.sample(5)
daf_1_habitacion.shape
# Out:
# (361, 8)

# %%
seleccion_final = (daf['Habitaciones'] == 1) & (daf['Valor'] < 4200)

daf_filtrado1 = daf[seleccion_final]
print(daf_filtrado1.sample(6))
daf_filtrado1.shape
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 6759         El Rosedal             1        1       0    35  2446.5
# 13781  Centro Histórico             1        0       0    35  3850.0
# 23813  Centro Histórico             1        0       0    42  3850.0
# 1062          Del Valle             1        0       1    45  2800.0
# 23005  Centro Histórico             1        0       0    40  3500.0
# 22306  Centro Histórico             1        0       0    40  3150.0
#
#        Condominio  Impuesto
# 6759        346.5       0.0
# 13781      1190.0      70.0
# 23813      1435.0       0.0
# 1062        420.0     108.5
# 23005      1400.0       0.0
# 22306      1400.0      73.5
# (361, 8)

# %% [markdown]
# ### 2.) Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
daf.shape
# Out:
# (14264, 8)

# %%
daf['Area'].agg(['mean','max','min']).round(2)
# Out:
# mean     125.2
# max     1200.0
# min       15.0
# Name: Area, dtype: float64

# %%
daf['Area'].describe().round(2)
# Out:
# count    14264.0
# mean       125.2
# std         95.5
# min         15.0
# 25%         70.0
# 50%         95.0
# 75%        150.0
# max       1200.0
# Name: Area, dtype: float64

# %%
seleccion_final2 = (daf['Habitaciones'] >= 2) & (daf['Valor']< 10500) & (daf['Area']>70)
daf_filtrado2 = daf[seleccion_final2]
print(daf.shape)
daf_filtrado2.sample(5)
# Out:
# (14264, 8)
#        Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 8251   Condesa             2        0       0    84  9800.0      2387.0
# 1904  Santa Fe             3        2       1    98  9800.0      5320.0
# 2293  Narvarte             3        0       0    75  5250.0      3069.5
# 7424  Santa Fe             2        1       1    82  8750.0      4550.0
# 139   Santa Fe             3        1       2    93  8750.0      3850.0
#
#       Impuesto
# 8251     402.5
# 1904     385.0
# 2293     126.0
# 7424       0.0
# 139        0.0

# %% [markdown]
# ## **Guardando los archivos**

# %%
daf.to_csv('Inmueblres_ml.csv', index=False,sep=';')

# %%
daf_filtrado1.to_csv('Inmueblres_ml_filtro1.csv', index=False,sep=';')

# %%
daf_filtrado2.to_csv('Inmueblres_ml_filtro2.csv', index=False,sep=';')

# %% [markdown]
# ## **Demandas de DEV**

# %% [markdown]
# ### **Crear columnas númericas**

# %% [markdown]
# #### **valor_mensual:** Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
pd.read_csv(url, sep =';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep =';')
datos.shape
# Out:
# (25121, 9)

# %%
datos['Valor_mensual'] = datos['Valor'] + datos['Condominio']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# #### **valor_anual:** Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
datos['Valor_anual'] = datos['Valor_mensual']*12 + datos['Impuesto']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN

# %% [markdown]
# ### **Crear columna categorica**

# %% [markdown]
# #### **Descripcion:** Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos['Descripcion'] = datos['Tipo'] + ' en la colonia: ' + datos['Colonia'] + \
                        ' con ' + datos['Habitaciones'].astype(str) + ' cuarto(s) y ' + \
                        datos['Garages'].astype(str) + ' plazas de estacionamiento'

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                                                                      Descripcion
# ...

# %%
datos['Descripcion'].sample(5)
# Out:
# 16335    Conjunto Comercial/Sala en la colonia: Centro Histórico con 0 cuarto(s) y 0 plazas de estacionamiento
# 280           Departamento en la colonia: San Miguel Chapultepec con 3 cuarto(s) y 3 plazas de estacionamiento
# 2845                          Casa Comercial en la colonia: Roma con 0 cuarto(s) y 2 plazas de estacionamiento
# 18438         Tienda en Centro Comercial en la colonia: Santa Fe con 0 cuarto(s) y 1 plazas de estacionamiento
# 10433                        Departamento en la colonia: Condesa con 2 cuarto(s) y 1 plazas de estacionamiento
# Name: Descripcion, dtype: object

# %% [markdown]
# ### **Tiene_suite:** Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
datos['Tiene_suite'] = datos['Suites'].apply(lambda x: 'Sí' if x > 0 else 'No')

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                                                                      Descripcion  \
# ...

# %%
datos.to_csv('Inmuebles_dev.csv',index=False,sep=';')
