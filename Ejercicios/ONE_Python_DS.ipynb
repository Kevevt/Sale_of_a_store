# %% [markdown]
# #### Instalando Matplotlib

# %%
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,4,9]); plt.show()

# %%
import matplotlib
print(matplotlib.__version__)

matplotlib.__version__
print
# Out:
# 3.10.1
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import matplotlib.pyplot as plt

# %%
estudiantes = ['Juan', 'Maria', 'Jose']
notas = [9, 8.5, 6.5]

# %%
plt.bar(x=estudiantes, height=notas)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
estudiantes
# Out:
# ['Juan', 'Maria', 'Jose']

# %%
estudiantes_2 = estudiantes
estudiantes_2
# Out:
# ['Juan', 'Maria', 'Jose']

# %%
import random

# %%
from random import choice as cho

# %%
estud = cho(estudiantes_2)
estud
# Out:
# 'Juan'

# %%
help(cho)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %% [markdown]
# ## Ejercicios, ya que verga

# %% [markdown]
# #### 3 - Crea un programa que lea la siguiente lista de números y elija uno al azar.

# %%
lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]
selec = cho(lista)
selec
# Out:
# 105

# %% [markdown]
# #### 4 - Crea un programa que genere aleatoriamente un número entero menor que 100.

# %%
import random
numero_aleatorio = random.randrange(100)
print(numero_aleatorio)
# Out:
# 3

# %% [markdown]
# #### 5 - Crea un programa que solicite a la persona usuaria ingresar dos números enteros y calcule la potencia del primer número elevado al segundo.

# %% [markdown]
# #### 6 - Se debe escribir un programa para sortear a un seguidor de una red social para ganar un premio. La lista de participantes está numerada y debemos elegir aleatoriamente un número según la cantidad de participantes. Pide a la persona usuaria que proporcione el número de participantes del sorteo y devuelve el número sorteado.

# %% [markdown]
# ## Pinches ejercicios culeros, que se vaya a la verga

# %%
agua = {"H": 13, "Ter": 1234, "HF":234}
len(agua)

print(pow(2,3))
# Out:
# 8

# %%
peso = float(input("Digita el peso, en kilogramos: "))
altura = float(input("Digita la altura, en metros: "))

imc = round(peso / pow(altura, 2), 2)

print(f"El IMC de la persona es: {imc}")
# Out:
# El IMC de la persona es: 18.42

# %% [markdown]
# ## **Ejercicios con funciones**.
# ### Situación 2:
# Recibimos una solicitud para crear una función que calcule el promedio de notas de un estudiante a partir de una lista; que permita alterar la
# cantidad de notas, y que no implique tener que modificar la función.
# Los datos recibidos, en esta ocasión, corresponden a una lista que contiene las notas de un mismo estudiante en una determinada materia.
# **notas:**  *83, 90, 6,0, 10.0*
#
# **¿Vamos a resolver este desafío?**
# Para facilitar nuestra comprensión del proceso, vamos a aplicar las notas de un único estudiante; sin embargo, puedes probar otros casos para
# practicar

# %%
kevin = [10, 10, 10,9.6, 9.8, 10, 9.7]
alex = [10, 8, 7, 5, 8, 9, 6]

def promediocalif(califica):
    return round(sum(califica)/len(califica),1)
    

kevcal = promediocalif(kevin)
print(kevcal)
type(kevcal)
# Out:
# 9.9
# float

# %% [markdown]
# ### Situación 3:
# Recibimos una nueva solicitud. Debemos calcular el promedio de un estudiante a partir de una lista y retornar tanto el promedio como la situación del estudiante *("Aprobado(a)" si la nota es mayor o igual a 7.0, en caso contrario, será "Reprobado(a)").*
#
# Además de ello, **necesitamos exhibir un pequeño texto para indicar el promedio del estudiante y cuál es su situación**. Los datos recibidos corresponden a una lista que contiene apenas las notas de un estudiante en una materia determinada.

# %%
notaasalex = [8.5, 9.0, 6.0, 10.0]
notakevin = [9.5, 9.0, 9.6, 10.0]
def califAprobado(listnotas):
    promedio = sum(listnotas)/len(listnotas)
    if promedio >= 7:
        situacion = 'Aprobó'
    else:
        situacion = 'Reprobó'
    return (round(promedio,2), situacion)
    
promedio, situacion = califAprobado(notakevin)
print((f'El estudiante tuvo un promedio de: {promedio}, por lo tanto {situacion}.'))
# Out:
# El estudiante tuvo un promedio de: 9.53, por lo tanto Aprobó.

# %%
notaasalexx = [8.5, 9.0, 6.0, 10.0]
notakevin = [9.5, 9.0, 9.6, 10.0]
notasgil = [6,5.1,4.5,7]
def califAprobado(listnotas): 
    promedio = sum(listnotas)/len(listnotas) 

    if promedio >= 7: 
        situacion = 'Aprobó' 
    else: 
        situacion = 'Reprobó' 
    return (f'El estudiante tuvo un promedio de: {round(promedio,2)}, por lo tanto {situacion}.') 

califAprobado(notakevin)
# Out:
# 'El estudiante tuvo un promedio de: 9.53, por lo tanto Aprobó.'

# %%
califAprobado(notaasalexx)
# Out:
# 'El estudiante tuvo un promedio de: 8.38, por lo tanto Aprobó.'

# %%
califAprobado(notasgil)
# Out:
# 'El estudiante tuvo un promedio de: 5.65, por lo tanto Reprobó.'

# %% [markdown]
# ## **Funciones Lambda**

# %% [markdown]
# #### Primer ejercicio

# %%
doble = lambda x: x*2
print(doble(5))
# Out:
# 10

# %%
x = 12
dado = 12
raz = lambda da : pow(da,.5)
print(raz(25))
# Out:
# 5.0

# %%
# 2) Con dos argumentos y default
suma = lambda a, b=0: a + b
print(suma(7))     # 7
print(suma(7, 2))  # 10
# Out:
# 7
# 9

# %% [markdown]
# ## **Lista de listas**

# %%
notas_grupo = [
    'Juan', 8.0, 9.0, 10.0,
    'Maria', 9.0, 7.0, 6.0,
    'José', 3.4, 7.0, 7.0,
    'Claudia', 5.5, 6.6, 8.0,
    'Ana', 6.0, 10.0, 9.5
]

# %%
notaestu = []
nombres = []

for i in notas_grupo:
    #print(i)
    if isinstance(i,str):
        nombres.append(i)
    else:
        notaestu.append(i)
print(nombres)
print(notaestu)
# Out:
# ['Juan', 'Maria', 'José', 'Claudia', 'Ana']
# [8.0, 9.0, 10.0, 9.0, 7.0, 6.0, 3.4, 7.0, 7.0, 5.5, 6.6, 8.0, 6.0, 10.0, 9.5]

# %%
notas_separadas = []
print(notaestu)

for i in range(0,len(notaestu),3):
    print(notaestu[i],notaestu[i+1], notaestu[i+2])
    notas_separadas.append(notaestu[i:i+3])

print(notas_separadas)
# Out:
# [8.0, 9.0, 10.0, 9.0, 7.0, 6.0, 3.4, 7.0, 7.0, 5.5, 6.6, 8.0, 6.0, 10.0, 9.5]
# 8.0 9.0 10.0
# 9.0 7.0 6.0
# 3.4 7.0 7.0
# 5.5 6.6 8.0
# 6.0 10.0 9.5
# [[8.0, 9.0, 10.0], [9.0, 7.0, 6.0], [3.4, 7.0, 7.0], [5.5, 6.6, 8.0], [6.0, 10.0, 9.5]]

# %%
b = []
b.extend("ok")     # ['o', 'k']     ← string se descompone
b.append("ok")     # ['ok']         ← string como un solo elemento
print(b)
# Out:
# ['o', 'k', 'ok']

# %% [markdown]
# ## **Situación 7:**
# Necesitamos generar una lista de tuplas con los nombres de los estudiantes y el código ID de cada uno de ellos para la plataforma de análisis de datos. La creación del código consiste en concatenar la primera letra del nombre del estudiante con un número aleatorio de 0 a 999. Los datos recibidos corresponden a una lista con los nombres de cada estudiante.
#
# **¿Vamos a resolver este desafío?**
# Para facilitar nuestra comprensión del proceso, vamos a trabajar con un grupo de 5 estudiantes; sin embargo, puedes probar otros casos para practicar.

# %%
nombres
# Out:
# ['Juan', 'Maria', 'José', 'Claudia', 'Ana']

# %%
from random import randint

# %%
def genera_numero():
    return randint(0,999)
print(genera_numero())
# Out:
# 268

# %%
idd = []
codigos_estudiantes = []
for i in nombres:
    combinacion = f'{i[0]}{genera_numero()}'
    codigos_estudiantes.append((i,combinacion))
print(codigos_estudiantes)
# Out:
# [('Juan', 'J692'), ('Maria', 'M401'), ('José', 'J754'), ('Claudia', 'C899'), ('Ana', 'A419')]

# %% [markdown]
# ## **Situación 8:**
# Recibimos la demanda de crear una lista con el promedio de los estudiantes de la lista de listas que creamos en la Situación 6, redondeando el promedio a una casilla decimal. Recordando que cada lista de la lista de listas contiene las tres notas de cada estudiante.

# %%
notas_separadas
# Out:
# [[8.0, 9.0, 10.0],
#  [9.0, 7.0, 6.0],
#  [3.4, 7.0, 7.0],
#  [5.5, 6.6, 8.0],
#  [6.0, 10.0, 9.5]]

# %%
notas_promedios = [round((i[0]+i[0+1]+i[0+2])/len(i),1) for i in notas_separadas]
notas_promedios
# Out:
# [9.0, 7.3, 5.8, 6.7, 8.5]

# %% [markdown]
# ## **Situación 9:**
# Ahora, necesitamos utilizar los promedios calculados en el ejemplo anterior, y agruparlos con el nombre de los respectivos estudiantes. Esto será necesario para generar una lista que seleccione a aquellos estudiantes que posean un promedio final mayor o igual a 8 para concursar por una beca de estudios para el próximo año lectivo. Los datos recibidos corresponden a una lista de tuplas con los nombres y los códigos de los estudiantes junto a la lista de promedios calculados previamente.
#
# **Nota: El número de código será diferente cada vez que se ejecute la celda que los genera, por lo tanto, es completamente normal que estos códigos sean diferentes.**
#
# ¿Vamos a resolver este desafío?

# %%
print(codigos_estudiantes)
print(notas_promedios)
# Out:
# [('Juan', 'J692'), ('Maria', 'M401'), ('José', 'J754'), ('Claudia', 'C899'), ('Ana', 'A419')]
# [9.0, 7.3, 5.8, 6.7, 8.5]

# %%
for codigo,notpro in zip(codigos_estudiantes,notas_promedios):
    nombe, cod = codigo
    completa = nombe,cod,notpro
    if notpro <8:
        print(f'El estudiante {nombe} tiene un promedio de: {notpro}, por lo tanto NO fué seleccionado para la BECA.')
    else:
        print(f'El estudiante {nombe} tiene un promedio de: {notpro}, por lo tanto Sí fué seleccionado para la BECA.')
# Out:
# El estudiante Juan tiene un promedio de: 9.0, por lo tanto Sí fué seleccionado para la BECA.
# El estudiante Maria tiene un promedio de: 7.3, por lo tanto NO fué seleccionado para la BECA.
# El estudiante José tiene un promedio de: 5.8, por lo tanto NO fué seleccionado para la BECA.
# El estudiante Claudia tiene un promedio de: 6.7, por lo tanto NO fué seleccionado para la BECA.
# El estudiante Ana tiene un promedio de: 8.5, por lo tanto Sí fué seleccionado para la BECA.

# %% [markdown]
# #### Con comprensión de lista

# %%
nombres = [nombre[0] for nombre in codigos_estudiantes]
nombres
# Out:
# ['Juan', 'Maria', 'José', 'Claudia', 'Ana']

# %%
estu_promedio = list(zip(nombres,notas_promedios))
estu_promedio
# Out:
# [('Juan', 9.0), ('Maria', 7.3), ('José', 5.8), ('Claudia', 6.7), ('Ana', 8.5)]

# %%
estu_beca = [estu[0] for estu in estu_promedio if estu[1]>=8]
print(f"Estos son los estudiantes con beca aprobada: {' y '.join(estu_beca)}.")
# Out:
# Estos son los estudiantes con beca aprobada: Juan y Ana.

# %% [markdown]
# ### Lista de aprobados

# %%
print(codigos_estudiantes,
notas_separadas,
notas_promedios, sep='\n')
# Out:
# [('Juan', 'J692'), ('Maria', 'M401'), ('José', 'J754'), ('Claudia', 'C899'), ('Ana', 'A419')]
# [[8.0, 9.0, 10.0], [9.0, 7.0, 6.0], [3.4, 7.0, 7.0], [5.5, 6.6, 8.0], [6.0, 10.0, 9.5]]
# [9.0, 7.3, 5.8, 6.7, 8.5]

# %%
aprobados = ['Estudiante Aprobado(a)' if promedio>=7 else 'Estudiante Reprobado(a)' for promedio in notas_promedios]
aprobados
# Out:
# ['Estudiante Aprobado(a)',
#  'Estudiante Aprobado(a)',
#  'Estudiante Reprobado(a)',
#  'Estudiante Reprobado(a)',
#  'Estudiante Aprobado(a)']

# %% [markdown]
# ## **Dict Comprehension**
#
# #### Ejercicios

# %% [markdown]
# 1 - Crea un código para imprimir la suma de los elementos de cada una de las listas contenidas en la siguiente lista:

# %%
lista_de_listas = [[4, 6, 5, 9], [1, 0, 7, 2], [3, 4, 1, 8]]

# %%
lista_suma = [sum(i) for i in lista_de_listas]
lista_suma
# Out:
# [24, 10, 16]

# %% [markdown]
# 2 - Crea un código para generar una lista que almacene el tercer elemento de cada tupla contenida en la siguiente lista de tuplas:

# %%
lista_de_tuplas = [('Pedro', 1.74, 81), ('Júlia', 1.65, 67), ('Otávio', 1.81, 83)]

# %%
peso_tupla = [elemento[2] for elemento in lista_de_tuplas]
peso_tupla
# Out:
# [81, 67, 83]

# %%
lista = []
for tupla in lista_de_tuplas:
    lista.append(tupla[2])
print(lista)
id(lista)
# Out:
# [81, 67, 83]
# 1386946278848

# %% [markdown]
# 3 - A partir de la lista: lista = ['Pedro', 'Júlia', 'Otávio', 'Eduardo'], crea un código para generar una lista de tuplas en la que cada tupla tenga el primer elemento como la posición del nombre en la lista original y el segundo elemento siendo el propio nombre.

# %%
lista = ['Pedro', 'Júlia', 'Otávio', 'Eduardo']

# %%
lista_tuplas = [(i+1,lista[i]) for i in range(len(lista))]
lista_tuplas
# Out:
# [(1, 'Pedro'), (2, 'Júlia'), (3, 'Otávio'), (4, 'Eduardo')]
