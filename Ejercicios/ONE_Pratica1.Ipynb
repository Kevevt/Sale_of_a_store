# %% [markdown]
# #### Pues ya toca la practica amarga.

# %%
'''if condicion:
    dfsfds
else:
    dfd'''

# %%
nom = 'Alura'
if nom == 'Alura':
    print('condición verdadera')
else:
    print('Condición falsa')
# Out:
# condición verdadera

# %%
num = 14
if num == 13 or num >= 14:
    print('Condición verdadera')
else:
    print('Condición falsa')
# Out:
# Condición verdadera

# %% [markdown]
# #### Ventas de Bruno

# %%
manzanas = int(input('Digite la cantidad de manzanas vendidas: '))
platanos = int(input('Digite la cantidad de platanos vendidos: '))

if manzanas > platanos:
    print(f'Las manzanas tuvieron mas ventas. Vendieron {manzanas-platanos} piezas más que los platanos.')
elif manzanas == platanos:
    print(f'Vendieron las mismas {manzanas} piezas cada una. ')
else:
    print(f'Los platanos tuvieron mas ventas. Vendieron {platanos-manzanas} piezas más que las manzanas.')

# %%
manzanas = int(input("Digite la cantidad de manzanas vendidas: "))
platanos = int(input("Digite la cantidad de plátanos vendidos: "))

if manzanas <=0 or platanos <=0:
    print("Valores inválidos")
else:
    diferencia = abs(manzanas - platanos)

    if manzanas > platanos:
        print(f"Las maanzanas tuvieron más ventas. Vendieron {diferencia} piezas más que los plátanos.")
    elif manzanas < platanos:
        print(f"Los plátanos tuvieron más ventas. Vendieron {diferencia} piezas más que las manzanas.")
    else:
        print(f"Vendieron las mismas {manzanas} piezas cada una.")
# Out:
# Valores inválidos

# %% [markdown]
# #### Lucas el trabajador de IT

# %%
tempe = int(input('Digite la temperatura actual: '))

if tempe > 25:
    print('¡Alerta! Temperatura por encima del límite permitido.')
else:
    print('La temperatura es chill')
# Out:
# ¡Alerta! Temperatura por encima del límite permitido.

# %% [markdown]
# #### Anna Júlia sistema para calcular el índice.

# %%
peso = float(input('Digite el peso (kg): '))
altura = float(input('Digite la altura (m): '))

imc = (peso)/(altura**2)

if 18.5 <= imc < 25:
    print(f'Su IMC es: {imc:.2f}\nTiene peso normal')
elif 18.5 >= imc:
    print(f'tu {imc:.2f}\nestá por debajo del limite inferior de 18.5 ICM.')
else:
    print(f'tu {imc:.2f}\nestá por arriba del limite superior de 25 ICM.')
# Out:
# Su IMC es: 22.46
# Tiene peso normal

# %% [markdown]
# #### Laura desarrolla un sistema para saber si una persona tiene derecho a recibir beneficio social.

# %%
ingresos = float(input('Digite sus ingresos: '))
hijos = float(input('Digite el número de hijos que tiene: '))

if ingresos <= 2000 and hijos >=1:
    print('Felicidades, Sí tienes drecho a recibir un beneficio social.')
else:
    print('No tienes derechos brote')
# Out:
# No tienes derechos brote

# %% [markdown]
# #### Una empresa evalua a sus empleados

# %%
pdesempeno = int(input('Ingrese la Puntuación de desempeño (0 a 10): '))
aniost = int(input('Ingrese los años trabajados: '))

if pdesempeno >= 7:
    if aniost > 5:
        print('Elegible para ascenso')
    else:
        print('Buen desempeño, sigue así')
else:
    print('Necesita mejorar.')
# Out:
# Necesita mejorar.

# %% [markdown]
# #### Desarrollando un pequeño juego.

# %%
numj = int(input('Digite el número: '))

if numj <=0:
    print('digite otro número.')
elif numj % 3 == 0 and numj % 5 == 0:
    print('Número mágico')
elif numj % 3 == 0:
    print('Divisible por 3')
elif numj % 5 == 0:
    print('Disivible por 5')
else:
    print('No es número mágico')
# Out:
# No es número mágico

# %% [markdown]
# #### Una escuela otorga becas

# %%
ingresof = int(input('Digite el ingreso familiar: '))
promedio = float(input('Digite el Promedio del estudiante: '))
asistencia = int(input('Digite el porcentaje de asisistencia (0-100): '))

if ingresof<1500 and promedio > 8 and asistencia > 90:
    print('Beca completa aprobada')
elif ingresof <2500 and promedio > 7 and asistencia > 85:
    print('Media Beca aprobada')
else:
    print('No elegible para beca')
# Out:
# No elegible para beca

# %% [markdown]
# #### Edad del pasajero

# %%
edad = int(input('Digite la edad del pasajero: '))
distancia = int(input('Digite la distancia del recorrido (km): '))

if edad < 6:
    print('viaja gratis')

if 6<= edad <= 18:
    if distancia <= 20:
        print('pagan $1.5 edad: 6 entre 18 y d-20')
    elif distancia > 20:
        print('$2.50 d+20')
    
if edad > 18:
    if distancia <= 20:
        print('$2.50 ed +18 y d-20')
    elif distancia > 20:
        print('+18, +20km = $4.00')
# Out:
# $2.50 ed +18 y d-20

# %% [markdown]
# #### Aquí vamos a resolver los ejercicios de Bucles.

# %%
clientes = ["Juan", "Maria", "Carlos", "Ana", "Beatriz"]

for c in clientes:
    print(c)
# Out:
# Juan
# Maria
# Carlos
# Ana
# Beatriz

# %% [markdown]
# #### Andre prueba una nueva función del Backend

# %%
contador = 0

while contador < 10:
    print(contador)
    contador += 1

# %% [markdown]
# #### Marco quiere mostrar un mensaje de bienbenida

# %%
for c in range(5):
    print('¡Bienbenido a Buscante!')

# %% [markdown]
# #### Valores - Tienda virtual

# %%
valores = [10, 20, 30, 40, 50]

print(sum(valores))

sumaval = 0
# Hay que definir la variable antes de entrar al bucle for?
for v in valores:
    sumaval += v
print(sumaval)
# Out:
# 150
# 150

# %% [markdown]
# #### Ana desarrolla su portafo

# %%
proyectos = ["sitio web", "juego", "análisis de datos", None, "aplicativo móvil"]

for p in proyectos:
    if p==None:
        print('Proyecto Ausente')
        continue
    print(p)
# Out:
# sitio web
# juego
# análisis de datos
# Proyecto Ausente
# aplicativo móvil

# %% [markdown]
# #### Jose está desarrollando una funcionalidad

# %%
libross = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

for l in libross:
    if l == "El Hobbit":
        print(f'Libro encontradoo: {l}')
        break

print()
libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

for libro in libros:
    if libro == "El Hobbit":
        print(f"Libro encontrado: {libro}")
        break

for lb in libros:
    if "El Hobbit" in lb:
        print(f"Libro encontrado: {lb}")
        break
# Out:
# Libro encontradoo: El Hobbit
#
# Libro encontrado: El Hobbit
# Libro encontrado: El Hobbit

# %% [markdown]
# #### Sistema de control de inventario para Bucante.

# %%
inventario = 5

for inv in range(inventario+1):
    inventario -=1
    if inventario == 0:
        print('Inventario agotado')
        break
    print(f'Venta realizada, Iventario restante: {inventario}')
# Out:
# Venta realizada, Iventario restante: 4
# Venta realizada, Iventario restante: 3
# Venta realizada, Iventario restante: 2
# Venta realizada, Iventario restante: 1
# Inventario agotado
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
inventario = 5

while inventario > 0:
  print("¡Venta realizada! Inventario restante: ", inventario)
  inventario -= 1
print("Inventario agotado")
# Out:
# ¡Venta realizada! Inventario restante:  5
# ¡Venta realizada! Inventario restante:  4
# ¡Venta realizada! Inventario restante:  3
# ¡Venta realizada! Inventario restante:  2
# ¡Venta realizada! Inventario restante:  1
# Inventario agotado

# %% [markdown]
# #### Aline mensajes personalizados

# %%
cuenta = 12

while cuenta >= 1:
    if cuenta % 2 == 0:
        print(f'Faltan solo {cuenta} segundos - ¡No pierdas esta oportunidad!')
    else:
        print(f'La cuenta continúa: {cuenta} segundos restantes.')
    cuenta -=1
print('¡Aprovecha la promoción ahora!')
# Out:
# Faltan solo 12 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 11 segundos restantes.
# Faltan solo 10 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 9 segundos restantes.
# Faltan solo 8 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 7 segundos restantes.
# Faltan solo 6 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 5 segundos restantes.
# Faltan solo 4 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 3 segundos restantes.
# Faltan solo 2 segundos - ¡No pierdas esta oportunidad!
# La cuenta continúa: 1 segundos restantes.
# ¡Aprovecha la promoción ahora!

# %% [markdown]
# #### Ana y su sistema de filtrado

# %%
libros = [
    {"nombre": "1984", "stock": 5},
    {"nombre": "Dom Casmurro", "stock": 0},
    {"nombre": "El Principito", "stock": 3},
    {"nombre": "El Hobbit", "stock": 0},
    {"nombre": "Orgullo y Prejuicio", "stock": 2}
]

for l in libros:
    if l["stock"] != 0:
        print(f'Libro disponible{l['nombre']}, con stock de: {l["stock"]}')
# Out:
# Libro disponible1984, con stock de: 5
# Libro disponibleEl Principito, con stock de: 3
# Libro disponibleOrgullo y Prejuicio, con stock de: 2

# %%
libros

for lob in libros:
    for k, v in lob.items():
        print(k,v)
# Out:
# nombre 1984
# stock 5
# nombre Dom Casmurro
# stock 0
# nombre El Principito
# stock 3
# nombre El Hobbit
# stock 0
# nombre Orgullo y Prejuicio
# stock 2

# %% [markdown]
# #### Sistema de registro de JOA

# %%
nameuser = input('Digite su nombre de usuario: ')
password = input('Digite su contraseña: ')

while len(nameuser) < 5 or len(password) < 8:
    if len(nameuser) < 5:
        print('EI nombre de usuario debe tener al menos 5 caracteres')
        nameuser = input('Digite su nombre de usuario: ')
        continue
    elif len(password) < 8:   
        print('La contraseña debe tener al menos 8 caracteres')
        password = input('Digite su contraseña: ')
        continue
print('Registro realizado con éxito')
